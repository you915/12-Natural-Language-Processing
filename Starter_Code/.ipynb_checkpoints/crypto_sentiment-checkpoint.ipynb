# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\richa\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv("example.env")
api_key = os.getenv("News_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_articles = newsapi.get_everything(q='bitcoin', language='en', sort_by='relevancy')
btc_articles
# Out:
# {'status': 'ok',
#  'totalResults': 4156,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Jonathan Shieber',
#    'title': 'Casa pivots to provide self-custody services to secure bitcoin',
#    'description': 'Casa, a Colorado-based provider of bitcoin security services, is launching a managed service allowing customers to buy and hold their own bitcoin, rather than using an external custodian like Coinbase. “With self-custody using Casa it’s impossible to be hacke…',
#    'url': 'http://techcrunch.com/2020/08/06/casa-pivots-to-provide-self-custody-services-to-secure-bitcoin/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/06/GettyImages-1050523528.jpg?w=600',
#    'publishedAt': '2020-08-06T18:25:29Z',
#    'content': 'Casa, a Colorado-based provider of bitcoin security services, is launching a managed service allowing customers to buy and hold their own bitcoin, rather than using an external custodian like Coinbas… [+1571 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Christine Fisher',
#    'title': 'Twitter hacker was previously caught stealing a fortune in Bitcoin',
#    'description': 'Graham Ivan Clark, the 17-year-old “mastermind” behind the massive Twitter breach that compromised high-profile accounts, like those belonging to Joe Biden and Elon Musk, got caught stealing hundreds of thousands of dollars worth of Bitcoins last year.\xa0Accord…',
#    'url': 'https://www.engadget.com/twitter-hacker-graham-clark-stolen-bitcoin-140234512.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2020-01%2Fe1c11890-42df-11ea-9fc7-677060cb72f6&client=amp-blogside-v2&signature=2974a9748770f53801158974991307682915bc05',
#    'publishedAt': '2020-08-03T14:02:34Z',
#    'content': 'In April, the Secret Service seized 100 Bitcoins from Clark, NYT reports. Weeks later, Bennett received a letter explaining that the Secret Service had recovered 100 of his Bitcoins. The letter cited… [+884 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Lily Hay Newman',
#    'title': 'The Quest to Liberate $300K of Bitcoin From an Old ZIP File',
#    'description': "The story of a guy who wouldn't let a few quintillion possible decryption keys stand between him and his cryptocurrency.",
#    'url': 'https://www.wired.com/story/quest-to-liberate-bitcoin-from-old-zip-file/',
#    'urlToImage': 'https://media.wired.com/photos/5f2b61c651a37c312e424bc1/191:100/w_1280,c_limit/security_crypto_916432942.jpg',
#    'publishedAt': '2020-08-06T16:16:32Z',
#    'content': "The question still remained, though, whether all that GPU-crunching would actually work. After months of hammering on the problem, Stay was finally ready to try. The Guy hadn't given the entire ZIP f… [+2880 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'John Biggs',
#    'title': 'This Ransomware Stole $25 Million in 5 Months',
#    'description': 'A ransomware variant called NetWalker is doing surprisingly well, even in this economy. The malware, which takes computers hostage and asks for a Bitcoin ransom, raked in $25 million in the last five months, a solid haul for what amounts to a solid ransomware…',
#    'url': 'https://gizmodo.com/this-ransomware-stole-25-million-in-5-months-1844609509',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/xpts6nwwp4jgsoqmmryt.jpg',
#    'publishedAt': '2020-08-04T20:30:00Z',
#    'content': 'A ransomware variant called NetWalker is doing surprisingly well, even in this economy. The malware, which takes computers hostage and asks for a Bitcoin ransom, raked in $25 million in the last five… [+1606 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'FBI and CISA warn against surge in voice phishing campaigns',
#    'description': 'Authorities saw an uptick in voice phishing (or “vishing”) campaigns after the pandemic forced companies to implement work-from-home arrangements. That’s what the Federal Bureau of Investigation (FBI) and the Cybersecurity and Infrastructure Security Agency (…',
#    'url': 'https://www.engadget.com/fbi-cisa-issue-voice-phishing-campaign-advisory-121936127.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2019-08%2F963d0510-bf49-11e9-beff-3f5e5758e121&client=amp-blogside-v2&signature=79d749ba8d928e91cc070a6e5de85e6011dad5c2',
#    'publishedAt': '2020-08-23T12:19:36Z',
#    'content': '“The COVID-19 pandemic has resulted in a mass shift to working from home, resulting in increased use of corporate VPN and elimination of in-person verification, which can partially explain the succes… [+3548 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Brian Barrett',
#    'title': 'Hackers Flood Reddit With Pro-Trump Takeovers',
#    'description': 'By apparently compromising moderator accounts, the attackers were able to plaster MAGA materials all over at least 70 popular subreddits.',
#    'url': 'https://www.wired.com/story/pro-trump-hackers-flood-reddit-maga-takeovers/',
#    'urlToImage': 'https://media.wired.com/photos/5f2db627fa7afed05b43792e/191:100/w_1280,c_limit/security_trump_1251054599.jpg',
#    'publishedAt': '2020-08-07T20:22:54Z',
#    'content': 'In what appears to be a massive coordinated strike against Reddit, hackers took over dozens of pages on Friday afternoon, using their access to plaster pro-Donald Trump imagery across subreddits with… [+3494 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Bitcoin hits highest in 13 months as 2020 rally gathers steam - Reuters',
#    'description': 'Bitcoin jumped to its highest in over a year on Monday, adding to a 2020 rally that has seen it more than treble in price since March.',
#    'url': 'https://www.reuters.com/article/us-crypto-currencies-idUSKCN25D1Z8',
#    'urlToImage': 'https://s2.reutersmedia.net/resources/r/?m=02&d=20200817&t=2&i=1529932525&w=1200&r=LYNXNPEG7G14I',
#    'publishedAt': '2020-08-17T15:59:00Z',
#    'content': 'LONDON (Reuters) - Bitcoin jumped to its highest in over a year on Monday, adding to a 2020 rally that has seen it more than treble in price since March. \r\nThe biggest cryptocurrency gained 4.4% to $… [+389 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘IMF says crypto may change how we buy, sell, save, and invest’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Faraday used to say: Time is money! Bitcoi…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/26/satoshi-nakaboto-imf-says-crypto-may-change-how-we-buy-sell-save-and-invest/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-26T09:41:43Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+2802 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘European app claims flight delay compensation for you in BTC’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Sloterdijk used to say: Money makes the wo…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/20/satoshi-nakaboto-european-app-claims-flight-delay-compensation-for-you-in-btc/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-20T08:55:11Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2968 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘4 of the 5 largest South Korean banks to offer crypto services’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Pasteur used to say: Yolo! Bitcoin price W…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/17/satoshi-nakaboto-4-of-the-5-largest-south-korean-banks-to-offer-crypto-services/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-17T08:59:41Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+2881 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Pranksters Stream Porn During Zoom Hearing for Alleged 17-Year-Old Twitter Hacker',
#    'description': 'Pranksters disrupted judicial hearings on Wednesday for the 17-year-old Florida kid who allegedly hijacked the accounts of prominent Twitter users last month, according to multiple people on the teleconference call. There were several intrusions during the fi…',
#    'url': 'https://gizmodo.com/pranksters-stream-porn-during-zoom-hearing-for-alleged-1844618440',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/q8ze1qfypdv1igx9oovh.png',
#    'publishedAt': '2020-08-05T15:30:00Z',
#    'content': 'Pranksters disrupted judicial hearings on Wednesday for the 17-year-old Florida kid who allegedly hijacked the accounts of prominent Twitter users last month, according to multiplepeople on the telec… [+1914 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin ends day above $12K for first time in a year’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Hegel used to say: Yippee! Bitcoin price W…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/18/satoshi-nakaboto-bitcoin-ends-day-above-12k-for-first-time-in-a-year/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-18T08:55:11Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2886 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin hovering above $10,000 for second-longest time ever’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Albert Einstein used to say: Fight the pow…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/24/satoshi-nakaboto-bitcoin-hovering-above-10000-for-second-longest-time-ever/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-24T08:57:05Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2632 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Fidelity launches Bitcoin index fund for wealthy investors’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Faraday used to say: Time is money! Bitcoi…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/27/satoshi-nakaboto-fidelity-launches-bitcoin-index-fund-for-wealthy-investors/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-27T10:32:55Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2786 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Winklevoss twins make the case for $500K Bitcoin’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Schopenhauer used to say: Yippee! Bitcoin …',
#    'url': 'https://thenextweb.com/hardfork/2020/08/28/satoshi-nakaboto-winklevoss-twins-make-the-case-for-500k-bitcoin/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-28T08:49:38Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2855 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Bitcoin is now worth as much as Netflix’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Habermass used to say: Crack open this tas…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/21/satoshi-nakaboto-bitcoin-is-now-worth-as-much-as-netflix/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-21T08:57:51Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3024 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Ryanair CEO believes Bitcoin is a ponzi scheme’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Marcus Aurelius used to say: Yippee! Bitco…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/25/satoshi-nakaboto-ryanair-ceo-believes-bitcoin-is-a-ponzi-scheme/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-25T08:54:43Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2986 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Swiss health insurer now accepts Bitcoin as payment’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Kant used to say: Your imagination is the …',
#    'url': 'https://thenextweb.com/hardfork/2020/09/01/satoshi-nakaboto-swiss-health-insurer-now-accepts-bitcoin-as-payment/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-09-01T08:57:56Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2863 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'Cryptocurrency exchange FTX acquires portfolio tracker Blockfolio',
#    'description': 'FTX, a cryptocurrency exchange that offers derivatives, options and other sophisticated products, is acquiring a popular portfolio tracking app, Blockfolio. FTX is spending $150 million for the acquisition. But take that price with a grain of salt as it’s a c…',
#    'url': 'http://techcrunch.com/2020/08/25/cryptocurrency-exchange-ftx-acquires-portfolio-tracker-blockfolio/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/10/bitcoin-andre-francois-mckenzie-iGYiBhdNTpE-unsplash.jpg?w=599',
#    'publishedAt': '2020-08-26T00:00:57Z',
#    'content': 'FTX, a cryptocurrency exchange that offers derivatives, options and other sophisticated products, is acquiring a popular portfolio tracking app, Blockfolio.\r\nFTX is spending $150 million for the acqu… [+1325 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Satoshi Nakaboto',
#    'title': 'Satoshi Nakaboto: ‘Big dog billionaire investor says Fed should add Bitcoin to its reserve’',
#    'description': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day. Welcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you what’s been going on with Bitcoin in the past 24 hours. As Descartes used to say: Fight the power! Bi…',
#    'url': 'https://thenextweb.com/hardfork/2020/08/19/satoshi-nakaboto-big-dog-billionaire-investor-says-fed-should-add-bitcoin-to-its-reserve/',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F08%2Fbitcoin_today-header_bitcoin_today.jpg&signature=30221b6a68049cc6bc3b58f3ddb38864',
#    'publishedAt': '2020-08-19T09:34:33Z',
#    'content': 'Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2861 chars]'}]}

# %%
# Fetch the Ethereum news articles
ethereum_articles = newsapi.get_everything(q='ethereum', language='en', sort_by='relevancy')
ethereum_articles
# Out:
# {'status': 'ok',
#  'totalResults': 1331,
#  'articles': [{'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'Crypto wallet MetaMask finally launches on iOS and Android, and it supports Apple Pay',
#    'description': "If you've interacted with cryptocurrencies in the past couple of years, there's a good chance you've used MetaMask. It's a cryptocurrency wallet in the form of a browser extension that supports Ethereum and its ecosystem, making it easy to connect with a dece…",
#    'url': 'https://mashable.com/article/metamask-ios-android/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F09%252F02%252Ffd%252Fe724b5edb4b644dba45958e17ad591e1.6b9c6.png%252F1200x630.png?signature=xIKBM112GVhTA9mUq0DRjCVGWSE=',
#    'publishedAt': '2020-09-02T16:00:00Z',
#    'content': "If you've interacted with cryptocurrencies in the past couple of years, there's a good chance you've used MetaMask. It's a cryptocurrency wallet in the form of a browser extension that supports Ether… [+2291 chars]"},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Joseph Green',
#    'title': 'Master blockchain with this cheap online course',
#    'description': "TL;DR: The Mega Blockchain Mastery Bundle is on sale for £29.81 as of August 17, saving you 97% on list price.\n\nCash isn't necessarily king anymore. You've probably heard that cryptocurrency and blockchain technologies (which power things like Bitcoin and Eth…",
#    'url': 'https://mashable.com/uk/shopping/aug-17-mega-blockchain-mastery-bundle/',
#    'urlToImage': 'https://mondrian.mashable.com/2020%252F08%252F17%252F40%252F5fe1250a25cd46bca29df0fa3c2e813f.4539c.png%252F1200x630.png?signature=PeH92TKb8dmntUe5Zygr2icxP4o=',
#    'publishedAt': '2020-08-17T04:00:00Z',
#    'content': "TL;DR: The Mega Blockchain Mastery Bundle is on sale for £29.81 as of August 17, saving you 97% on list price.\r\nCash isn't necessarily king anymore. You've probably heard that cryptocurrency and bloc… [+1286 chars]"},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Nate Nead',
#    'title': 'How to Make Your Own Crytocurrency',
#    'description': 'Bitcoin, Ethereum, Litecoin, and a handful of other cryptocurrencies have broken into the mainstream, but what if you want to start a cryptocurrency of your own? There are many valid motivations for doing so. For example, you may not like how the mainstream c…',
#    'url': 'https://readwrite.com/2020/09/01/how-to-make-your-own-crytocurrency/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2020/09/make-your-own-crytopcurrency.jpg',
#    'publishedAt': '2020-09-01T19:42:11Z',
#    'content': None},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Tom Wilson',
#    'title': 'Boom or bust? Welcome to the freewheeling world of crypto lending - Reuters',
#    'description': 'It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of about 20%. What could possibly go wrong?',
#    'url': 'https://www.reuters.com/article/us-crypto-currencies-lending-insight-idUSKBN25M0GP',
#    'urlToImage': 'https://s4.reutersmedia.net/resources/r/?m=02&d=20200826&t=2&i=1531031482&w=1200&r=LYNXMPEG7P0BU',
#    'publishedAt': '2020-08-26T06:07:00Z',
#    'content': 'LONDON (Reuters) - It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of about 20%. What could possibly g… [+7143 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Irrera',
#    'title': "ConsenSys acquires JPMorgan's blockchain platform Quorum - Reuters",
#    'description': "Brooklyn-based technology startup ConsenSys has acquired JPMorgan Chase & Co's marquee blockchain platform Quorum, the companies said on Tuesday.",
#    'url': 'https://www.reuters.com/article/us-jpmorgan-consensys-quorum-idUSKBN25L1MR',
#    'urlToImage': 'https://s4.reutersmedia.net/resources_v2/images/rcom-default.png',
#    'publishedAt': '2020-08-25T13:01:00Z',
#    'content': 'NEW YORK (Reuters) - Brooklyn-based technology startup ConsenSys has acquired JPMorgan Chase &amp; Co’s (JPM.N) marquee blockchain platform Quorum, the companies said on Tuesday. \r\nAs part of the dea… [+1915 chars]'},
#   {'source': {'id': None, 'name': 'The Daily Hodl'},
#    'author': 'Daily Hodl Staff',
#    'title': 'Million-Dollar Bitcoin Whale Says Traders Should Track Two Altcoins in Addition to BTC - The Daily Hodl',
#    'description': '<ol><li>Million-Dollar Bitcoin Whale Says Traders Should Track Two Altcoins in Addition to BTC\xa0\xa0The Daily Hodl\r\n</li><li>Trader Who Earned USD 11m Shares Trading Techniques, Offers Advice\xa0\xa0Cryptonews\r\n</li><li>Blockchain Bites: Hashrates Drop, Bitcoiners Hodl…',
#    'url': 'https://dailyhodl.com/2020/08/19/million-dollar-bitcoin-whale-says-traders-should-track-two-altcoins-in-addition-to-btc/',
#    'urlToImage': 'https://i2.wp.com/dailyhodl.com/wp-content/uploads/2020/04/cob2821me.jpg?fit=810%2C475&ssl=1',
#    'publishedAt': '2020-08-19T07:04:25Z',
#    'content': 'An outspoken Bitcoin whale who rarely shows affection for anything other than BTC says two crypto assets have potential.\r\nThe pseudonymous trader known as Joe007 says UNUS SED LEO (LEO) may be a soli… [+1503 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Emily Graffeo',
#    'title': "Gold 'certainly' could soar as high as $3000, famed investor Michael Novogratz says",
#    'description': '<ul>\n<li>Michael Novogratz told Bloomberg the price of gold could certainly get up to $3,000.\xa0</li>\n<li>The Galaxy Digital CEO and co-founder said the next Fed meeting could be the "juice that accelerates gold and bitcoin."</li>\n<li>Novogratz is a bitcoin inv…',
#    'url': 'https://www.businessinsider.com/gold-price-outlook-certainly-could-soar-michael-novogratz-investor-target-2020-8',
#    'urlToImage': 'https://images.markets.businessinsider.com/image/5f36ebfde89ebf001f044d74-2400/2015-05-06t120000z_1090059811_gf10000086138_rtrmadp_3_usa-business.jpg',
#    'publishedAt': '2020-08-14T20:13:44Z',
#    'content': 'REUTERS/Rick Wilking\r\n<ul><li>Michael Novogratz told Bloomberg the price of gold could certainly get up to $3,000.\xa0</li><li>The Galaxy Digital CEO and co-founder said the next Fed meeting could be th… [+1981 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Jared Polites',
#    'title': 'How DeFi Will Reshape Financial Services',
#    'description': 'Decentralized Finance continues to mature and attract significant capital investment.',
#    'url': 'https://www.entrepreneur.com/article/354018',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1596216067-GettyImages-1056292582.jpg',
#    'publishedAt': '2020-08-04T16:00:00Z',
#    'content': 'August\r\n4, 2020\r\n5 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nIf you have been an active or casual participant in the blockchain industry, you have likely heard of dece… [+5924 chars]'},
#   {'source': {'id': None, 'name': 'Hongkiat.com'},
#    'author': 'Ashutosh KS',
#    'title': 'Top 10 Ethereum Exchanges to Buy and Sell ETH',
#    'description': "Ethereum is one of the most growing cryptocurrencies in the recent times And if you're looking forward to investing in the world's first peer-to-peer",
#    'url': 'https://www.hongkiat.com/blog/buy-sell-exchange-ethereum/',
#    'urlToImage': 'https://assets.hongkiat.com/uploads/buy-sell-exchange-ethereum/coinbase-user-dashboard.jpg?14-09-2017',
#    'publishedAt': '2020-08-11T13:46:23Z',
#    'content': 'Ethereum is one of the most growing cryptocurrencies in the recent times\r\n And if you’re looking forward to investing in the world’s first peer-to-peer computing network, then you’re not the only one… [+11039 chars]'},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': "ConsenSys acquires JP Morgan Chase's Quorum enterprise blockchain project, while the bank makes a strategic investment in ConsenSys (Ian Allison/CoinDesk)",
#    'description': "Ian Allison / CoinDesk:\nConsenSys acquires JP Morgan Chase's Quorum enterprise blockchain project, while the bank makes a strategic investment in ConsenSys\xa0 —\xa0 Quorum, the enterprise blockchain platform developed by mega-bank JPMorgan Chase, being acquired by…",
#    'url': 'https://www.techmeme.com/200825/p22',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2019/05/consensys-delcastillo-4-e1558953549735_edited.jpg',
#    'publishedAt': '2020-08-25T16:30:02Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Techmeme.com'},
#    'author': None,
#    'title': 'Researchers say thousands of ERC-20 tokens, together worth $1B+, implemented flawed smart contracts while some exchanges improperly verify token transactions (Ada Hui/CoinDesk)',
#    'description': 'Ada Hui / CoinDesk:\nResearchers say thousands of ERC-20 tokens, together worth $1B+, implemented flawed smart contracts while some exchanges improperly verify token transactions\xa0 —\xa0 Over $1 billion worth of tokens on the Ethereum blockchain are missing a soft…',
#    'url': 'https://www.techmeme.com/200825/p28',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/08/ivan-vranic-j9-2LIZ2_Rc-unsplash.jpg',
#    'publishedAt': '2020-08-25T18:10:01Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Billy Bambrough, Contributor, Billy Bambrough, Contributorhttps://www.forbes.com/sites/billybambrough/',
#    'title': 'Ethereum Is Eating Bitcoin',
#    'description': 'Ethereum, having long played second fiddle to the number one cryptocurrency, bitcoin, is stepping into the limelight...',
#    'url': 'https://www.forbes.com/sites/billybambrough/2020/09/01/ethereum-is-eating-bitcoin/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f4eb82259ba0eb47d12a595%2F0x0.jpg',
#    'publishedAt': '2020-09-01T23:30:00Z',
#    'content': 'Ethereum, having long played second fiddle to the number one cryptocurrency, bitcoin, is stepping into the limelight.\r\nThe ethereum price, climbing more than 10% over the last 24-hour trading period … [+2813 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Christopher Brookins, Contributor, Christopher Brookins, Contributorhttps://www.forbes.com/sites/christopherbrookins/',
#    'title': 'Ethereum Soars 10% Overnight — Implications For Bitcoin',
#    'description': 'If DeFi can find a legitimate use case for synthetic bitcoin, $BTC could begin to benefit from the same feedback loop as Ethereum, thus an additional boost to price beyond its current store of value utilization.',
#    'url': 'https://www.forbes.com/sites/christopherbrookins/2020/09/01/ethereum-soars-10-overnight---implications-for-bitcoin/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f4e60068de0165e005c61b8%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D3199%26cropY1%3D314%26cropY2%3D1814',
#    'publishedAt': '2020-09-01T15:53:09Z',
#    'content': 'POLAND - 2020/06/15: In this photo illustration an Ethereum logo seen displayed on a smartphone. ... [+] (Photo Illustration by Mateusz Slodkowski/SOPA Images/LightRocket via Getty Images)\r\nSOPA Imag… [+2371 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Joseph Young, Contributor, Joseph Young, Contributorhttps://www.forbes.com/sites/youngjoseph/',
#    'title': 'Two Biggest Threats To The Ongoing Bitcoin And Ethereum Rallies',
#    'description': 'The price of Bitcoin rose to as high as $12,086 on Coinbase, as Ethereum (ETH) buoyed overall market sentiment.',
#    'url': 'https://www.forbes.com/sites/youngjoseph/2020/09/01/bitcoin-dollar-ethereum/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f4eb2097f66e47e53e18c77%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D5000%26cropY1%3D263%26cropY2%3D3076',
#    'publishedAt': '2020-09-01T20:43:58Z',
#    'content': 'The price of Bitcoin looks to enter a new range after a key breakout.\r\nSOPA Images/LightRocket via Getty Images\r\nThe price of Bitcoin rose to as high as $12,086 on Coinbase, as Ethereum (ETH) buoyed … [+3138 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'William Foxley',
#    'title': 'Ethereum 2.0 Testnet Medalla Goes Live With 20,000 Validators',
#    'description': 'Medalla, the final testnet before the anticipated launch of Ethereum 2.0 later this year, is now live, the Ethereum Foundation announced Tuesday.',
#    'url': 'https://www.coindesk.com/ethereum-2-0-testnet-medalla-goes-live-with-20000-validators',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2019/08/aya-ethereum.jpg',
#    'publishedAt': '2020-08-04T15:00:30Z',
#    'content': 'Ethereum 2.0s final and official public testnet, Medalla, is now live, according to the Ethereum Foundation.\r\n<ul><li>Medalla is the final testnet before the launch of the Eth 2.0 network, which is t… [+1386 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Joseph Young, Contributor, Joseph Young, Contributorhttps://www.forbes.com/sites/youngjoseph/',
#    'title': '$418 To $302 To $385: Why Ethereum Saw Extreme 30% Price Moves In 15 Minutes',
#    'description': 'The entire sequence of events happened in a total of 15 minutes. Ethereum hit $418, then dropped to $302, and rebounded to $385, recording a 25% drop and a 27% upsurge, respectively.',
#    'url': 'https://www.forbes.com/sites/youngjoseph/2020/08/02/ethereum-extreme-price-movements/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f272b274e7abefa93b6fb6e%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D4300%26cropY1%3D218%26cropY2%3D2637',
#    'publishedAt': '2020-08-02T21:11:42Z',
#    'content': 'On Aug. 2, the price of Ethereum peaked at $418; then, within 5 minutes, it dropped by 25%. On Binance Futures, ETH plunged to as low as $302, before recovering back to $385 within 10 minutes.\r\nThe e… [+3470 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'John Navin, Contributor, John Navin, Contributorhttps://www.forbes.com/sites/johnnavin/',
#    'title': 'Bitcoin, Litecoin, Ethereum: When They Move, They All Move Together',
#    'description': 'After long weeks of mostly just sideways, Bitcoin and its cryptocurrency friends finally made a move and it was upward.',
#    'url': 'https://www.forbes.com/sites/johnnavin/2020/08/03/bitcoin-litecoin-ethereum-when-they-movethey-all-move-together/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f287d53bef01107bfabc2e7%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D6000%26cropY1%3D0%26cropY2%3D3375',
#    'publishedAt': '2020-08-03T21:15:45Z',
#    'content': 'usa one hundred dollar banknotes among the binary code background, crypto currency and internet ... [+] technology banking concept. Fintech or digital currencies.\r\ngetty\r\nAfter long weeks of mostly j… [+4043 chars]'},
#   {'source': {'id': 'vice-news', 'name': 'Vice News'},
#    'author': 'Lorenzo Franceschi-Bicchierai, Emanuel Maiberg',
#    'title': 'Hackers Hijacked Popular YouTube Channels to Promote Bitcoin Scams',
#    'description': 'Several popular YouTube channels streamed Bitcoin scams in a series of hacks to promote Bitcoin scams.',
#    'url': 'https://www.vice.com/en_us/article/m7jxm8/hackers-hijacked-popular-youtube-channels-bitcoin-scams',
#    'urlToImage': 'https://video-images.vice.com//articles/5f3172987788ed0096ded0ef/lede/1597077089517-screen-shot-2020-08-10-at-123006-pm.png?image-resize-opts=Y3JvcD0wLjg5NjZ4dzowLjk5OXhoOzAuMDM5N3h3LDAuMDAxeGgmcmVzaXplPTEyMDA6KiZyZXNpemU9MTIwMDoq',
#    'publishedAt': '2020-08-10T16:35:09Z',
#    'content': 'Last week, hackers took control of several popular YouTube channels to broadcast a scam,\xa0 asking people to send in Bitcoin with the empty promise of sending more cryptocurrency back.\xa0\r\nThe hackers hi… [+3643 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'Daniel Cawrey',
#    'title': 'Market Wrap: Bitcoin Rebounds to $11.5K; Ethereum’s Gas Woes Worsen',
#    'description': 'Bitcoin’s price is bouncing back as Ethereum fees cause problems.',
#    'url': 'https://www.coindesk.com/market-wrap-bitcoin-ethereum-gas',
#    'urlToImage': 'https://static.coindesk.com/wp-content/uploads/2020/08/cdbpiaug12-scaled.jpg',
#    'publishedAt': '2020-08-12T20:29:35Z',
#    'content': 'Bitcoin is making up for lost gains after hitting a one-week low. Over on Ethereum, the fee situation continues to be problematic for traders.\r\n<ul><li>Bitcoin (BTC) trading around $11,595 as of 20:0… [+4142 chars]'},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'Rally launches Creator Coin cryptocurrency for influencers',
#    'description': 'Rally is launching a cryptocurrency dubbed Creator Coin that will help influencers, content creators, and streamers run their own virtual economies.',
#    'url': 'https://venturebeat.com/2020/08/06/rally-launches-creator-coin-cryptocurrency-for-influencers/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2020/08/rally-2.jpg?w=1200&strip=all',
#    'publishedAt': '2020-08-06T16:00:13Z',
#    'content': 'Rally is launching a cryptocurrency dubbed Creator Coin that will help influencers, content creators, and streamers run their own virtual economies. And while its all virtual, Creator Coin is a new w… [+12652 chars]'}]}

# %%
# Create a function - Create the sentiment scores DataFrame
def get_sentiment_scores(article_type, key_word):
    sentiments = []
    for article in article_type["articles"]:
        try:
            text = article[key_word]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]

            sentiments.append({"text": text,
                               "date": date,
                               "compound": compound,
                               "positive": pos,
                               "negative": neg,
                               "neutral": neu
                               })
        except AttributeError:
            pass
    
    # Create DataFrame
    df = pd.DataFrame(sentiments)
    return df

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiment_df = get_sentiment_scores(btc_articles, 'content')
btc_sentiment_df
# Out:
#                                                  text        date  compound  \
# 0   Casa, a Colorado-based provider of bitcoin sec...  2020-08-06    0.5994
# 1   In April, the Secret Service seized 100 Bitcoi...  2020-08-03    0.0000
# 2   The question still remained, though, whether a...  2020-08-06   -0.0516
# 3   A ransomware variant called NetWalker is doing...  2020-08-04    0.5106
# 4   “The COVID-19 pandemic has resulted in a mass ...  2020-08-23    0.2732
# 5   In what appears to be a massive coordinated st...  2020-08-07   -0.1280
# 6   LONDON (Reuters) - Bitcoin jumped to its highe...  2020-08-17    0.3818
# 7   Our robot colleague Satoshi Nakaboto writes ab...  2020-08-26    0.5070
# 8   Our robot colleague Satoshi Nakaboto writes ab...  2020-08-20    0.5070
# 9   Our robot colleague Satoshi Nakaboto writes ab...  2020-08-17    0.5070
# 10  Pranksters disrupted judicial hearings on Wedn...  2020-08-05    0.3182
# 11  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-18    0.5070
# 12  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-24    0.5070
# 13  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-27    0.5070
# 14  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-28    0.5070
# 15  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-21    0.5070
# 16  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-25    0.5070
# 17  Our robot colleague Satoshi Nakaboto writes ab...  2020-09-01    0.5070
# 18  FTX, a cryptocurrency exchange that offers der...  2020-08-26    0.7506
# 19  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-19    0.5070
#
#     positive  negative  neutral
# 0      0.149     0.000    0.851
# 1      0.000     0.000    1.000
# 2      0.065     0.071    0.864
# 3      0.122     0.000    0.878
# 4      0.063     0.000    0.937
# 5      0.000     0.046    0.954
# 6      0.069     0.000    0.931
# 7      0.090     0.000    0.910
# 8      0.090     0.000    0.910
# 9      0.090     0.000    0.910
# 10     0.073     0.000    0.927
# 11     0.090     0.000    0.910
# 12     0.090     0.000    0.910
# 13     0.090     0.000    0.910
# 14     0.090     0.000    0.910
# 15     0.090     0.000    0.910
# 16     0.090     0.000    0.910
# 17     0.090     0.000    0.910
# 18     0.198     0.000    0.802
# 19     0.090     0.000    0.910

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiment_df = get_sentiment_scores(ethereum_articles, 'content')
ethereum_sentiment_df
# Out:
#                                                  text        date  compound  \
# 0   If you've interacted with cryptocurrencies in ...  2020-09-02    0.7506
# 1   TL;DR: The Mega Blockchain Mastery Bundle is o...  2020-08-17    0.0000
# 2   LONDON (Reuters) - It sounds like a surefire b...  2020-08-26    0.7579
# 3   NEW YORK (Reuters) - Brooklyn-based technology...  2020-08-25    0.0000
# 4   An outspoken Bitcoin whale who rarely shows af...  2020-08-19   -0.2677
# 5   REUTERS/Rick Wilking\r\n<ul><li>Michael Novogr...  2020-08-14    0.3400
# 6   August\r\n4, 2020\r\n5 min read\r\nOpinions ex...  2020-08-04    0.5423
# 7   Ethereum is one of the most growing cryptocurr...  2020-08-11    0.2484
# 8   Ethereum, having long played second fiddle to ...  2020-09-01    0.4019
# 9   POLAND - 2020/06/15: In this photo illustratio...  2020-09-01    0.0000
# 10  The price of Bitcoin looks to enter a new rang...  2020-09-01    0.0000
# 11  Ethereum 2.0s final and official public testne...  2020-08-04    0.0000
# 12  On Aug. 2, the price of Ethereum peaked at $41...  2020-08-02   -0.2732
# 13  usa one hundred dollar banknotes among the bin...  2020-08-03    0.0000
# 14  Last week, hackers took control of several pop...  2020-08-10   -0.1027
# 15  Bitcoin is making up for lost gains after hitt...  2020-08-12   -0.5994
# 16  Rally is launching a cryptocurrency dubbed Cre...  2020-08-06    0.4019
#
#     positive  negative  neutral
# 0      0.209     0.000    0.791
# 1      0.000     0.000    1.000
# 2      0.181     0.000    0.819
# 3      0.000     0.000    1.000
# 4      0.045     0.074    0.881
# 5      0.072     0.000    0.928
# 6      0.123     0.000    0.877
# 7      0.057     0.000    0.943
# 8      0.110     0.000    0.890
# 9      0.000     0.000    1.000
# 10     0.000     0.000    1.000
# 11     0.000     0.000    1.000
# 12     0.000     0.052    0.948
# 13     0.000     0.000    1.000
# 14     0.129     0.139    0.732
# 15     0.062     0.189    0.749
# 16     0.080     0.000    0.920

# %%
# Describe the Bitcoin Sentiment
btc_sentiment_df.describe()
# Out:
#         compound   positive   negative   neutral
# count  20.000000  20.000000  20.000000  20.00000
# mean    0.411560   0.086450   0.005850   0.90770
# std     0.225249   0.042427   0.018457   0.03952
# min    -0.128000   0.000000   0.000000   0.80200
# 25%     0.365900   0.072000   0.000000   0.91000
# 50%     0.507000   0.090000   0.000000   0.91000
# 75%     0.507000   0.090000   0.000000   0.91425
# max     0.750600   0.198000   0.071000   1.00000

# %%
# Describe the Ethereum Sentiment
ethereum_sentiment_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  17.000000  17.000000  17.000000  17.000000
# mean    0.129412   0.062824   0.026706   0.910471
# std     0.367736   0.067970   0.056512   0.091491
# min    -0.599400   0.000000   0.000000   0.732000
# 25%     0.000000   0.000000   0.000000   0.877000
# 50%     0.000000   0.057000   0.000000   0.928000
# 75%     0.401900   0.110000   0.000000   1.000000
# max     0.757900   0.209000   0.189000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin - 0.069150
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum - 0.771700
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin - 0.184000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
lemmatizer = WordNetLemmatizer()
sw = set(stopwords.words('english'))

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)

    # Convert the words to lowercase
    words = word_tokenize(re_clean.lower())
    
    # Remove the stop words
    words = [word for word in words if word not in sw]
    
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    
    return tokens

# %%
btc_sentiment_df["text"]
# Out:
# 0     Casa, a Colorado-based provider of bitcoin sec...
# 1     In April, the Secret Service seized 100 Bitcoi...
# 2     The question still remained, though, whether a...
# 3     A ransomware variant called NetWalker is doing...
# 4     “The COVID-19 pandemic has resulted in a mass ...
# 5     In what appears to be a massive coordinated st...
# 6     LONDON (Reuters) - Bitcoin jumped to its highe...
# 7     Our robot colleague Satoshi Nakaboto writes ab...
# 8     Our robot colleague Satoshi Nakaboto writes ab...
# 9     Our robot colleague Satoshi Nakaboto writes ab...
# 10    Pranksters disrupted judicial hearings on Wedn...
# 11    Our robot colleague Satoshi Nakaboto writes ab...
# 12    Our robot colleague Satoshi Nakaboto writes ab...
# 13    Our robot colleague Satoshi Nakaboto writes ab...
# 14    Our robot colleague Satoshi Nakaboto writes ab...
# 15    Our robot colleague Satoshi Nakaboto writes ab...
# 16    Our robot colleague Satoshi Nakaboto writes ab...
# 17    Our robot colleague Satoshi Nakaboto writes ab...
# 18    FTX, a cryptocurrency exchange that offers der...
# 19    Our robot colleague Satoshi Nakaboto writes ab...
# Name: text, dtype: object

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\richa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
# Create a new tokens column for Bitcoin
btc_sentiment_df['tokens'] = btc_sentiment_df['text'].apply(tokenizer)
btc_sentiment_df
# Out:
#                                                  text        date  compound  \
# 0   Casa, a Colorado-based provider of bitcoin sec...  2020-08-06    0.5994
# 1   In April, the Secret Service seized 100 Bitcoi...  2020-08-03    0.0000
# 2   The question still remained, though, whether a...  2020-08-06   -0.0516
# 3   A ransomware variant called NetWalker is doing...  2020-08-04    0.5106
# 4   “The COVID-19 pandemic has resulted in a mass ...  2020-08-23    0.2732
# 5   In what appears to be a massive coordinated st...  2020-08-07   -0.1280
# 6   LONDON (Reuters) - Bitcoin jumped to its highe...  2020-08-17    0.3818
# 7   Our robot colleague Satoshi Nakaboto writes ab...  2020-08-26    0.5070
# 8   Our robot colleague Satoshi Nakaboto writes ab...  2020-08-20    0.5070
# 9   Our robot colleague Satoshi Nakaboto writes ab...  2020-08-17    0.5070
# 10  Pranksters disrupted judicial hearings on Wedn...  2020-08-05    0.3182
# 11  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-18    0.5070
# 12  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-24    0.5070
# 13  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-27    0.5070
# 14  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-28    0.5070
# 15  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-21    0.5070
# 16  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-25    0.5070
# 17  Our robot colleague Satoshi Nakaboto writes ab...  2020-09-01    0.5070
# 18  FTX, a cryptocurrency exchange that offers der...  2020-08-26    0.7506
# 19  Our robot colleague Satoshi Nakaboto writes ab...  2020-08-19    0.5070
#
#     positive  negative  neutral  \
# 0      0.149     0.000    0.851
# 1      0.000     0.000    1.000
# 2      0.065     0.071    0.864
# 3      0.122     0.000    0.878
# 4      0.063     0.000    0.937
# 5      0.000     0.046    0.954
# 6      0.069     0.000    0.931
# 7      0.090     0.000    0.910
# 8      0.090     0.000    0.910
# 9      0.090     0.000    0.910
# 10     0.073     0.000    0.927
# 11     0.090     0.000    0.910
# 12     0.090     0.000    0.910
# 13     0.090     0.000    0.910
# 14     0.090     0.000    0.910
# 15     0.090     0.000    0.910
# 16     0.090     0.000    0.910
# 17     0.090     0.000    0.910
# 18     0.198     0.000    0.802
# 19     0.090     0.000    0.910
#
#                                                tokens
# 0   [casa, coloradobased, provider, bitcoin, secur...
# 1   [april, secret, service, seized, bitcoins, cla...
# 2   [question, still, remained, though, whether, g...
# 3   [ransomware, variant, called, netwalker, surpr...
# 4   [covid, pandemic, resulted, mass, shift, worki...
# 5   [appears, massive, coordinated, strike, reddit...
# 6   [london, reuters, bitcoin, jumped, highest, ye...
# 7   [robot, colleague, satoshi, nakaboto, writes, ...
# 8   [robot, colleague, satoshi, nakaboto, writes, ...
# 9   [robot, colleague, satoshi, nakaboto, writes, ...
# 10  [prankster, disrupted, judicial, hearing, wedn...
# 11  [robot, colleague, satoshi, nakaboto, writes, ...
# 12  [robot, colleague, satoshi, nakaboto, writes, ...
# 13  [robot, colleague, satoshi, nakaboto, writes, ...
# 14  [robot, colleague, satoshi, nakaboto, writes, ...
# 15  [robot, colleague, satoshi, nakaboto, writes, ...
# 16  [robot, colleague, satoshi, nakaboto, writes, ...
# 17  [robot, colleague, satoshi, nakaboto, writes, ...
# 18  [ftx, cryptocurrency, exchange, offer, derivat...
# 19  [robot, colleague, satoshi, nakaboto, writes, ...

# %%
# Create a new tokens column for Ethereum
ethereum_sentiment_df['tokens'] = ethereum_sentiment_df['text'].apply(tokenizer)
ethereum_sentiment_df
# Out:
#                                                  text        date  compound  \
# 0   If you've interacted with cryptocurrencies in ...  2020-09-02    0.7506
# 1   TL;DR: The Mega Blockchain Mastery Bundle is o...  2020-08-17    0.0000
# 2   LONDON (Reuters) - It sounds like a surefire b...  2020-08-26    0.7579
# 3   NEW YORK (Reuters) - Brooklyn-based technology...  2020-08-25    0.0000
# 4   An outspoken Bitcoin whale who rarely shows af...  2020-08-19   -0.2677
# 5   REUTERS/Rick Wilking\r\n<ul><li>Michael Novogr...  2020-08-14    0.3400
# 6   August\r\n4, 2020\r\n5 min read\r\nOpinions ex...  2020-08-04    0.5423
# 7   Ethereum is one of the most growing cryptocurr...  2020-08-11    0.2484
# 8   Ethereum, having long played second fiddle to ...  2020-09-01    0.4019
# 9   POLAND - 2020/06/15: In this photo illustratio...  2020-09-01    0.0000
# 10  The price of Bitcoin looks to enter a new rang...  2020-09-01    0.0000
# 11  Ethereum 2.0s final and official public testne...  2020-08-04    0.0000
# 12  On Aug. 2, the price of Ethereum peaked at $41...  2020-08-02   -0.2732
# 13  usa one hundred dollar banknotes among the bin...  2020-08-03    0.0000
# 14  Last week, hackers took control of several pop...  2020-08-10   -0.1027
# 15  Bitcoin is making up for lost gains after hitt...  2020-08-12   -0.5994
# 16  Rally is launching a cryptocurrency dubbed Cre...  2020-08-06    0.4019
#
#     positive  negative  neutral  \
# 0      0.209     0.000    0.791
# 1      0.000     0.000    1.000
# 2      0.181     0.000    0.819
# 3      0.000     0.000    1.000
# 4      0.045     0.074    0.881
# 5      0.072     0.000    0.928
# 6      0.123     0.000    0.877
# 7      0.057     0.000    0.943
# 8      0.110     0.000    0.890
# 9      0.000     0.000    1.000
# 10     0.000     0.000    1.000
# 11     0.000     0.000    1.000
# 12     0.000     0.052    0.948
# 13     0.000     0.000    1.000
# 14     0.129     0.139    0.732
# 15     0.062     0.189    0.749
# 16     0.080     0.000    0.920
#
#                                                tokens
# 0   [youve, interacted, cryptocurrencies, past, co...
# 1   [tldr, mega, blockchain, mastery, bundle, sale...
# 2   [london, reuters, sound, like, surefire, bet, ...
# 3   [new, york, reuters, brooklynbased, technology...
# 4   [outspoken, bitcoin, whale, rarely, show, affe...
# 5   [reutersrick, wilkingullimichael, novogratz, t...
# 6   [august, min, readopinions, expressed, entrepr...
# 7   [ethereum, one, growing, cryptocurrencies, rec...
# 8   [ethereum, long, played, second, fiddle, numbe...
# 9   [poland, photo, illustration, ethereum, logo, ...
# 10  [price, bitcoin, look, enter, new, range, key,...
# 11  [ethereum, final, official, public, testnet, m...
# 12  [aug, price, ethereum, peaked, within, minute,...
# 13  [usa, one, hundred, dollar, banknote, among, b...
# 14  [last, week, hacker, took, control, several, p...
# 15  [bitcoin, making, lost, gain, hitting, oneweek...
# 16  [rally, launching, cryptocurrency, dubbed, cre...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

btc_tokens = get_token(btc_sentiment_df)
ethereum_tokens = get_token(ethereum_sentiment_df)

# %%
def bigram_counter(tokens, N): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(tokens)
    processed = tokenizer(big_string)
    bigrams = ngrams(processed, n=N)
    return dict(Counter(bigrams).most_common(10))

# %%
# Generate the Bitcoin N-grams where N=2
bit_ngram = bigram_counter(btc_tokens, 2)

# %%
# Generate the Ethereum N-grams where N=2
eth_ngram = bigram_counter(ethereum_tokens, 2)
# Out:
# {('char', 'ethereum'): 3,
#  ('photo', 'illustration'): 2,
#  ('imageslightrocket', 'via'): 2,
#  ('via', 'getty'): 2,
#  ('price', 'bitcoin'): 2,
#  ('creator', 'coin'): 2,
#  ('youve', 'interacted'): 1,
#  ('interacted', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'past'): 1,
#  ('past', 'couple'): 1}

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(btc_tokens, 10)
# Out:
# [('bitcoin', 37),
#  ('satoshi', 22),
#  ('nakaboto', 22),
#  ('char', 20),
#  ('robot', 11),
#  ('colleague', 11),
#  ('writes', 11),
#  ('every', 11),
#  ('fucking', 11),
#  ('daywelcome', 11)]

# %%
# Get the top 10 words for Ethereum
token_count(ethereum_tokens, 10)
# Out:
# [('char', 17),
#  ('ethereum', 9),
#  ('bitcoin', 6),
#  ('cryptocurrency', 5),
#  ('price', 5),
#  ('one', 4),
#  ('youve', 3),
#  ('blockchain', 3),
#  ('could', 3),
#  ('new', 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_tokens))
plt.title("Bitcoin Word Cloud", fontsize = 40)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(ethereum_tokens))
plt.title("Ethereum Word Cloud", fontsize = 40)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.3.1 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz#egg=en_core_web_sm==2.3.1 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (2.3.1)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from en_core_web_sm==2.3.1) (2.3.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.19.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.24.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.9.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.7.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.48.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.3)
# Requirement already satisfied: thinc==7.4.1 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: setuptools in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (47.3.0.post20200616)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\richa\anaconda3\envs\dev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_content = ' '.join(btc_sentiment_df['text'])
btc_content
# Out:
# "Casa, a Colorado-based provider of bitcoin security services, is launching a managed service allowing customers to buy and hold their own bitcoin, rather than using an external custodian like Coinbas… [+1571 chars] In April, the Secret Service seized 100 Bitcoins from Clark, NYT reports. Weeks later, Bennett received a letter explaining that the Secret Service had recovered 100 of his Bitcoins. The letter cited… [+884 chars] The question still remained, though, whether all that GPU-crunching would actually work. After months of hammering on the problem, Stay was finally ready to try. The Guy hadn't given the entire ZIP f… [+2880 chars] A ransomware variant called NetWalker is doing surprisingly well, even in this economy. The malware, which takes computers hostage and asks for a Bitcoin ransom, raked in $25 million in the last five… [+1606 chars] “The COVID-19 pandemic has resulted in a mass shift to working from home, resulting in increased use of corporate VPN and elimination of in-person verification, which can partially explain the succes… [+3548 chars] In what appears to be a massive coordinated strike against Reddit, hackers took over dozens of pages on Friday afternoon, using their access to plaster pro-Donald Trump imagery across subreddits with… [+3494 chars] LONDON (Reuters) - Bitcoin jumped to its highest in over a year on Monday, adding to a 2020 rally that has seen it more than treble in price since March. \r\nThe biggest cryptocurrency gained 4.4% to $… [+389 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+2802 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2968 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the … [+2881 chars] Pranksters disrupted judicial hearings on Wednesday for the 17-year-old Florida kid who allegedly hijacked the accounts of prominent Twitter users last month, according to multiplepeople on the telec… [+1914 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2886 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2632 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2786 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2855 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+3024 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2986 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in … [+2863 chars] FTX, a cryptocurrency exchange that offers derivatives, options and other sophisticated products, is acquirin ...

# %%
# Run the NER processor on all of the text
doc = nlp(btc_content)

# Add a title to the document
doc.user_data["title"] = "BITCOIN NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BITCOIN NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Casa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Colorado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based provider of bitcoin security services, is launching a managed service allowing customers to buy and hold their own bitcoin, rather than using an external custodian like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+1571 chars] In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Secret Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  seized
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , NYT reports.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weeks later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bennett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  received a letter explaining that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Secret Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had recovered
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of his Bitcoins. The letter cited… [+884 chars] The question still remained, though, whether all that GPU-crunching would actually work. After
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of hammering on the problem, Stay was finally ready to try. The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  hadn't given the entire ZIP f… [+2880 chars] A ransomware variant called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NetWalker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is doing surprisingly well, even in this economy. The malware, which takes computers hostage and asks for a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ransom, raked in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $25 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# … [+1606 chars] “The COVID-19 pandemic has resulted in a mass shift to working from home, resulting in increased use of corporate
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VPN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and elimination of in-person verification, which can partially explain the succes… [+3548 chars] In what appears to be a massive coordinated strike against
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reddit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , hackers took
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     over dozens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase;

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Casa ORG
# Colorado GPE
# Coinbas ORG
# April DATE
# the Secret Service ORG
# 100 CARDINAL
# Bitcoins ORG
# Clark GPE
# Weeks later DATE
# Bennett PERSON
# the Secret Service ORG
# 100 CARDINAL
# months DATE
# Guy PERSON
# NetWalker ORG
# Bitcoin GPE
# $25 million MONEY
# the last five DATE
# VPN PRODUCT
# Reddit ORG
# over dozens CARDINAL
# Friday DATE
# afternoon TIME
# pro-Donald Trump PERSON
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# over a year DATE
# Monday DATE
# 2020 DATE
# March DATE
# 4.4% PERCENT
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Wednesday DATE
# 17-year-old DATE
# Florida GPE
# Twitter ORG
# last month DATE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Blockfolio GPE
# FTX ORG
# $150 million MONEY
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_content = ' '.join(ethereum_sentiment_df['text'])
eth_content
# Out:
# "If you've interacted with cryptocurrencies in the past couple of years, there's a good chance you've used MetaMask. It's a cryptocurrency wallet in the form of a browser extension that supports Ether… [+2291 chars] TL;DR: The Mega Blockchain Mastery Bundle is on sale for £29.81 as of August 17, saving you 97% on list price.\r\nCash isn't necessarily king anymore. You've probably heard that cryptocurrency and bloc… [+1286 chars] LONDON (Reuters) - It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of about 20%. What could possibly g… [+7143 chars] NEW YORK (Reuters) - Brooklyn-based technology startup ConsenSys has acquired JPMorgan Chase &amp; Co’s (JPM.N) marquee blockchain platform Quorum, the companies said on Tuesday. \r\nAs part of the dea… [+1915 chars] An outspoken Bitcoin whale who rarely shows affection for anything other than BTC says two crypto assets have potential.\r\nThe pseudonymous trader known as Joe007 says UNUS SED LEO (LEO) may be a soli… [+1503 chars] REUTERS/Rick Wilking\r\n<ul><li>Michael Novogratz told Bloomberg the price of gold could certainly get up to $3,000.\xa0</li><li>The Galaxy Digital CEO and co-founder said the next Fed meeting could be th… [+1981 chars] August\r\n4, 2020\r\n5 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nIf you have been an active or casual participant in the blockchain industry, you have likely heard of dece… [+5924 chars] Ethereum is one of the most growing cryptocurrencies in the recent times\r\n And if you’re looking forward to investing in the world’s first peer-to-peer computing network, then you’re not the only one… [+11039 chars] Ethereum, having long played second fiddle to the number one cryptocurrency, bitcoin, is stepping into the limelight.\r\nThe ethereum price, climbing more than 10% over the last 24-hour trading period … [+2813 chars] POLAND - 2020/06/15: In this photo illustration an Ethereum logo seen displayed on a smartphone. ... [+] (Photo Illustration by Mateusz Slodkowski/SOPA Images/LightRocket via Getty Images)\r\nSOPA Imag… [+2371 chars] The price of Bitcoin looks to enter a new range after a key breakout.\r\nSOPA Images/LightRocket via Getty Images\r\nThe price of Bitcoin rose to as high as $12,086 on Coinbase, as Ethereum (ETH) buoyed … [+3138 chars] Ethereum 2.0s final and official public testnet, Medalla, is now live, according to the Ethereum Foundation.\r\n<ul><li>Medalla is the final testnet before the launch of the Eth 2.0 network, which is t… [+1386 chars] On Aug. 2, the price of Ethereum peaked at $418; then, within 5 minutes, it dropped by 25%. On Binance Futures, ETH plunged to as low as $302, before recovering back to $385 within 10 minutes.\r\nThe e… [+3470 chars] usa one hundred dollar banknotes among the binary code background, crypto currency and internet ... [+] technology banking concept. Fintech or digital currencies.\r\ngetty\r\nAfter long weeks of mostly j… [+4043 chars] Last week, hackers took control of several popular YouTube channels to broadcast a scam,\xa0 asking people to send in Bitcoin with the empty promise of sending more cryptocurrency back.\xa0\r\nThe hackers hi… [+3643 chars] Bitcoin is making up for lost gains after hitting a one-week low. Over on Ethereum, the fee situation continues to be problematic for traders.\r\n<ul><li>Bitcoin (BTC) trading around $11,595 as of 20:0… [+4142 chars] Rally is launching a cryptocurrency dubbed Creator Coin that will help influencers, content creators, and streamers run their own virtual economies. And while its all virtual, Creator Coin is a new w… [+12652 chars]"

# %%
# Run the NER processor on all of the text
doc = nlp(eth_content)

# Add a title to the document
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">If you've interacted with cryptocurrencies in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past couple of years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , there's a good chance you've used MetaMask. It's a cryptocurrency wallet in the form of a browser extension that supports Ether… [+2291 chars] TL;DR: The Mega Blockchain Mastery Bundle is on sale for £
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29.81
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , saving you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# </br>Cash isn't necessarily king anymore. You've probably heard that cryptocurrency and bloc… [+1286 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - It sounds like a surefire bet. You lend money to a borrower who puts up collateral that exceeds the size of the loan, and then you earn interest of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 20%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# . What could possibly g… [+7143 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEW YORK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based technology startup
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ConsenSys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has acquired
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JPMorgan Chase &amp;amp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; Co’s (JPM.N) marquee blockchain platform
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quorum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , the companies said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>As part of the dea… [+1915 chars] An outspoken
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  whale who rarely shows affection for anything other than
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The pseudonymous trader known as Joe007 says
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNUS SED LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LEO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) may be a soli… [+1503 chars] REUTERS/
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick Wilking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>&lt;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ul&gt;&lt;li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# &gt;
# <mark cl

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# the past couple of years DATE
# 29.81 MONEY
# August 17 DATE
# 97% PERCENT
# LONDON GPE
# Reuters ORG
# about 20% PERCENT
# NEW YORK PERSON
# Reuters ORG
# Brooklyn GPE
# ConsenSys ORG
# JPMorgan Chase &amp ORG
# Quorum PRODUCT
# Tuesday DATE
# Bitcoin GPE
# BTC ORG
# two CARDINAL
# UNUS SED LEO ORG
# LEO ORG
# Rick Wilking PERSON
# ul><li PERSON
# Michael Novogratz PERSON
# Bloomberg PERSON
# up to $3,000 MONEY
# The Galaxy Digital ORG
# Fed ORG
# August DATE
# 4 DATE
# 2020 DATE
# 5 CARDINAL
# one CARDINAL
# first ORDINAL
# second ORDINAL
# one CARDINAL
# bitcoin GPE
# more than 10% PERCENT
# 24-hour TIME
# Ethereum ORG
# Mateusz Slodkowski/ PERSON
# Bitcoin GPE
# Bitcoin GPE
# as high as $12,086 MONEY
# Ethereum (ETH ORG
# Medalla PERSON
# the Ethereum Foundation ORG
# ul><li PERSON
# Medalla GPE
# Aug. 2 DATE
# 418 MONEY
# 5 minutes TIME
# 25% PERCENT
# Binance Futures ORG
# ETH ORG
# as low as $302 MONEY
# 385 MONEY
# 10 minutes TIME
# one hundred dollar MONEY
# Fintech ORG
# Last week DATE
# YouTube PRODUCT
# Bitcoin GPE
# Bitcoin GPE
# one-week DATE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $11,595 MONEY
# 20:0 CARDINAL
# Creator Coin PERSON
# Creator Coin PERSON

# %% [markdown]
# ---
